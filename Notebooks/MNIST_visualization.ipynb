# %% [markdown]
# # Neural Network Training Visualization

# %% [markdown]
# ### Import the graph module from Utils

# %%
import json
import sys
import os
from pathlib import Path
from typing import Optional

import altair as alt
import pandas as pd

# Añadir el directorio padre al path para acceder al paquete Utils
notebook_dir = os.path.dirname(os.path.abspath('../__file__'))
sys.path.insert(0, os.path.abspath(notebook_dir))

# Importar funciones del dataset y utilidades desde el paquete Utils
from Utils.ComparationGraphs import compare_runs, load_from_paths, load_training_folder, runs_metadata, load_from_paths

# %% [markdown]
# ### Define functions for comparassion

# %%
def main(folder: str = "../stats"):

    runs = load_training_folder(folder)  

    print(runs_metadata(runs).to_string())

    chart = compare_runs(runs)
    chart.display()
    return 0

# %% [markdown]
# ### Physical Testing
#
# <img src="../Images/Captura de pantalla 2026-03-11 152052.png">

# %%
main("../stats/MNIST/PhysicalCPU")
# Out:
#   ✔  Loaded '1workerPhy'  ←  1workerPhy_metadata.json
#   ✔  Loaded '2workersPhy'  ←  2workersPhy_metadata.json
#   ✔  Loaded '3workersPhy'  ←  3workersPhy_metadata.json
#   ✔  Loaded '4workersPhy'  ←  4workersPhy_metadata.json
#
# 4 run(s) loaded from '/home/walviz/Documents/Personal files/Universidad/Semestre 10/ClienteServidor/BasicN-N/stats/MNIST/PhysicalCPU'.
#
#              test_acc (%)  epochs  learning_rate  train_time (s)  arch_hidden  num_partitions              architecture
# model
# 1workerPhy      92.409524     500            0.1      425.320465          128               1  Distributed with Sockets
# 2workersPhy     92.228571     500            0.1      342.974631          128               2  Distributed with Sockets
# 3workersPhy     92.057143     500            0.1      302.422000          128               3  Distributed with Sockets
# 4workersPhy     91.904762     500            0.1      279.555000          128               4  Distributed with Sockets
# [DEBUG] 1workerPhy → epoch=51, time=51, acc=51, loss=51
# [DEBUG] 2workersPhy → epoch=51, time=51, acc=51, loss=51
# [DEBUG] 3workersPhy → epoch=51, time=51, acc=51, loss=51
# [DEBUG] 4workersPhy → epoch=51, time=51, acc=51, loss=51
# [DEBUG] Final dataframe shape: (204, 5)
# alt.VConcatChart(...)
# 0

# %% [markdown]
# # GOOGLEC CLOUD TESTING
#
# ### StandarCPU
#
# <img src="../Images/e2-standarcpu/machineType.png">
# <h1></h1>
# <img src="../Images/e2-standarcpu/Workers.png"> <img src="../Images/e2-standarcpu/RIP.png"><h1></h1>
# <img src="../Images/e2-standarcpu/Training3Workers.png"><h1></h1>
# <img src="../Images/e2-standarcpu/Training4Workers.png"><h1></h1>

# %%
main("../stats/MNIST/standarCPU")
# Out:
#   ✔  Loaded '1workerStandarCPU'  ←  1worker_metadata.json
#   ✔  Loaded '2workersStandarCPU'  ←  2workers_metadata.json
#   ✔  Loaded '3workersStandarCPU'  ←  3workers_metadata.json
#   ✔  Loaded '4workersStandarCPU'  ←  4workers_metadata.json
#   ✔  Loaded '5workersStandarCPU'  ←  5workers_metadata.json
#
# 5 run(s) loaded from '/home/walviz/Documents/Personal files/Universidad/Semestre 10/ClienteServidor/BasicN-N/stats/MNIST/standarCPU'.
#
#                     test_acc (%)  epochs  learning_rate  train_time (s)  arch_hidden  num_partitions              architecture
# model
# 1workerStandarCPU      92.628571     500            0.1      775.424832          128               1  Distributed with Sockets
# 2workersStandarCPU     92.123810     500            0.1      606.824895          128               2  Distributed with Sockets
# 3workersStandarCPU     92.257143     500            0.1      577.163487          128               3  Distributed with Sockets
# 4workersStandarCPU     92.057143     500            0.1      703.809762          128               4  Distributed with Sockets
# 5workersStandarCPU     92.038095     500            0.1      651.333000          128               5  Distributed with Sockets
# [DEBUG] 1workerStandarCPU → epoch=51, time=51, acc=51, loss=51
# [DEBUG] 2workersStandarCPU → epoch=51, time=51, acc=51, loss=51
# [DEBUG] 3workersStandarCPU → epoch=51, time=51, acc=51, loss=51
# [DEBUG] 4workersStandarCPU → epoch=51, time=51, acc=51, loss=51
# [DEBUG] 5workersStandarCPU → epoch=51, time=51, acc=51, loss=51
# [DEBUG] Final dataframe shape: (255, 5)
# alt.VConcatChart(...)
# 0

# %% [markdown]
# ### HighCPU
#
# <img src='../Images/e2-highcpu-4/MachineType.png'><h1></h1>
# <img src='../Images/e2-highcpu-4/Trainning2Workers.png'>

# %%
main("../stats/MNIST/HIGHCPU")
# Out:
#   ✔  Loaded '1WorkerHIGHCPU'  ←  HighCPU1Worker_metadata.json
#   ✔  Loaded '2WorkersHIGHCPU'  ←  HighCPU2Workers_metadata.json
#
# 2 run(s) loaded from '/home/walviz/Documents/Personal files/Universidad/Semestre 10/ClienteServidor/BasicN-N/stats/MNIST/HIGHCPU'.
#
#                  test_acc (%)  epochs  learning_rate  train_time (s)  arch_hidden  num_partitions              architecture
# model
# 1WorkerHIGHCPU      92.080952     500            0.1      427.521076          128               1  Distributed with Sockets
# 2WorkersHIGHCPU     92.295238     500            0.1      390.204535          128               2  Distributed with Sockets
# [DEBUG] 1WorkerHIGHCPU → epoch=51, time=51, acc=51, loss=51
# [DEBUG] 2WorkersHIGHCPU → epoch=51, time=51, acc=51, loss=51
# [DEBUG] Final dataframe shape: (102, 5)
# alt.VConcatChart(...)
# 0

# %% [markdown]
# ### Y si se corre en un solo computador con varios workers ?
#
# <img src="../Images/image.png">

# %%
main("../stats/MNIST/Monolitic")
# Out:
#   ✔  Loaded '2WorkersRyzen'  ←  2WorkersRyzen_metadata.json
#   ✔  Loaded '3WorkersRyzen'  ←  3WorkersRyzen_metadata.json
#   ✔  Loaded '4WorkersRyzen'  ←  4WorkersRyzen_metadata.json
#   ✔  Loaded 'Ryzen3_1Worker'  ←  Ryzen31Worker_metadata.json
#
# 4 run(s) loaded from '/home/walviz/Documents/Personal files/Universidad/Semestre 10/ClienteServidor/BasicN-N/stats/MNIST/Monolitic'.
#
#                 test_acc (%)  epochs  learning_rate  train_time (s)  arch_hidden  num_partitions              architecture
# model
# 2WorkersRyzen      92.271429     500            0.1      288.593789          128               2  Distributed with Sockets
# 3WorkersRyzen      92.147619     500            0.1      284.206697          128               3  Distributed with Sockets
# 4WorkersRyzen      92.185714     500            0.1      294.235272          128               4  Distributed with Sockets
# Ryzen3_1Worker     92.142857     500            0.1      242.874441          128               1  Distributed with Sockets
# [DEBUG] 2WorkersRyzen → epoch=51, time=51, acc=51, loss=51
# [DEBUG] 3WorkersRyzen → epoch=51, time=51, acc=51, loss=51
# [DEBUG] 4WorkersRyzen → epoch=51, time=51, acc=51, loss=51
# [DEBUG] Ryzen3_1Worker → epoch=51, time=51, acc=51, loss=51
# [DEBUG] Final dataframe shape: (204, 5)
# alt.VConcatChart(...)
# 0

# %% [markdown]
# # Cositas interesante
#
# Comportamiento de solo con 2 workers

# %%
runs = load_from_paths(
    "../stats/MNIST/PhysicalCPU/2workersPhy_metadata.json",
    "../stats/MNIST/HIGHCPU/HighCPU2Workers_metadata.json",
    "../stats/MNIST/standarCPU/2workers_metadata.json",
    "../stats/MNIST/Monolitic/2WorkersRyzen_metadata.json",
)

print(runs_metadata(runs).to_string())

chart = compare_runs(runs)
chart.display()
# Out:
#   ✔  Loaded '2workersPhy'  ←  2workersPhy_metadata.json
#   ✔  Loaded '2WorkersHIGHCPU'  ←  HighCPU2Workers_metadata.json
#   ✔  Loaded '2workersStandarCPU'  ←  2workers_metadata.json
#   ✔  Loaded '2WorkersRyzen'  ←  2WorkersRyzen_metadata.json
#
# 4 run(s) loaded.
#
#                     test_acc (%)  epochs  learning_rate  train_time (s)  arch_hidden  num_partitions              architecture
# model
# 2workersPhy            92.228571     500            0.1      342.974631          128               2  Distributed with Sockets
# 2WorkersHIGHCPU        92.295238     500            0.1      390.204535          128               2  Distributed with Sockets
# 2workersStandarCPU     92.123810     500            0.1      606.824895          128               2  Distributed with Sockets
# 2WorkersRyzen          92.271429     500            0.1      288.593789          128               2  Distributed with Sockets
# [DEBUG] 2workersPhy → epoch=51, time=51, acc=51, loss=51
# [DEBUG] 2WorkersHIGHCPU → epoch=51, time=51, acc=51, loss=51
# [DEBUG] 2workersStandarCPU → epoch=51, time=51, acc=51, loss=51
# [DEBUG] 2WorkersRyzen → epoch=51, time=51, acc=51, loss=51
# [DEBUG] Final dataframe shape: (204, 5)
# alt.VConcatChart(...)

# %% [markdown]
# # COMPARASION DE LOS MEJORES

# %%
runs = load_from_paths(
    "../stats/MNIST/PhysicalCPU/4workersPhy_metadata.json",
    "../stats/MNIST/HIGHCPU/HighCPU2Workers_metadata.json",
    "../stats/MNIST/standarCPU/3workers_metadata.json",
    "../stats/MNIST/Monolitic/Ryzen31Worker_metadata.json",
)

print(runs_metadata(runs).to_string())

chart = compare_runs(runs)
chart.display()
# Out:
#   ✔  Loaded '4workersPhy'  ←  4workersPhy_metadata.json
#   ✔  Loaded '2WorkersHIGHCPU'  ←  HighCPU2Workers_metadata.json
#   ✔  Loaded '3workersStandarCPU'  ←  3workers_metadata.json
#   ✔  Loaded 'Ryzen3_1Worker'  ←  Ryzen31Worker_metadata.json
#
# 4 run(s) loaded.
#
#                     test_acc (%)  epochs  learning_rate  train_time (s)  arch_hidden  num_partitions              architecture
# model
# 4workersPhy            91.904762     500            0.1      279.555000          128               4  Distributed with Sockets
# 2WorkersHIGHCPU        92.295238     500            0.1      390.204535          128               2  Distributed with Sockets
# 3workersStandarCPU     92.257143     500            0.1      577.163487          128               3  Distributed with Sockets
# Ryzen3_1Worker         92.142857     500            0.1      242.874441          128               1  Distributed with Sockets
# [DEBUG] 4workersPhy → epoch=51, time=51, acc=51, loss=51
# [DEBUG] 2WorkersHIGHCPU → epoch=51, time=51, acc=51, loss=51
# [DEBUG] 3workersStandarCPU → epoch=51, time=51, acc=51, loss=51
# [DEBUG] Ryzen3_1Worker → epoch=51, time=51, acc=51, loss=51
# [DEBUG] Final dataframe shape: (204, 5)
# alt.VConcatChart(...)
