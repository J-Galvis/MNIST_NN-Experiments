# %% [markdown]
# # Neural Network Training Visualization

# %% [markdown]
# ### Import the graph module from Utils

# %%
import json
import sys
import os
from pathlib import Path
from typing import Optional

import altair as alt
import pandas as pd

# Añadir el directorio padre al path para acceder al paquete Utils
notebook_dir = os.path.dirname(os.path.abspath('../__file__'))
sys.path.insert(0, os.path.abspath(notebook_dir))

# Importar funciones del dataset y utilidades desde el paquete Utils
from Utils.ComparationGraphs import compare_runs, load_from_paths, load_training_folder, runs_metadata, load_from_paths

# %% [markdown]
# ### Define functions for comparassion

# %%
def main(folder: str = "../stats"):

    runs = load_training_folder(folder)  

    print(runs_metadata(runs).to_string())

    chart = compare_runs(runs, loose=False)
    chart.display()
    return 0

# %% [markdown]
# ### Physical Testing
#
# <img src="../Images/CIFAR10/image.png">

# %%
main("../stats/CIFAR_10")
# Out:
#   ✔  Loaded 'One worker Ryzen 3 4300U'  ←  oneWorker.json
#   ✔  Loaded 'Two I9-12900'  ←  twoWorkers.json
#
# 2 run(s) loaded from '/home/walviz/Documents/Personal files/Universidad/Semestre 10/ClienteServidor/BasicN-N/stats/CIFAR_10'.
#
#                           test_acc (%)  epochs  learning_rate  train_time (s)  arch_hidden  num_partitions              architecture
# model
# One worker Ryzen 3 4300U         63.52      40            0.1      27216.7251          128               1  Distributed with Sockets
# Two I9-12900                     53.43      40            0.1       5622.2188          128               2  Distributed with Sockets
# [DEBUG] One worker Ryzen 3 4300U → epoch=40, time=40, acc=40, loss=0
# [DEBUG] Two I9-12900 → epoch=40, time=40, acc=40, loss=0
# [DEBUG] Final dataframe shape: (80, 5)
# alt.VConcatChart(...)
# 0
